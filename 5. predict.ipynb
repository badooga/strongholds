# %%
import strongholds
import strongholds.graphing as mplt

import numpy as np

from matplotlib import pyplot as plt, gridspec
import ipywidgets

fixed_rng = np.random.default_rng(0)

# %%
heatmap = strongholds.generation_heatmap(2*10**5, ring_nums=range(3), rng=fixed_rng, concatenate=False)

grid = strongholds.generation_grid(range(3))

# %%
predict = strongholds.Predict(grid=grid, heatmap=heatmap, rng=fixed_rng)
predict.add_throw(strongholds.polarpoint(2500, np.pi/4), 80, 0.1)
predict.cumulative_probs.view(threshold=1e-3)
# Out:
# [((80.0, 2064.0), 0.033589101878104155),
#  ((96.0, 2064.0), 0.03245908286748052),
#  ((-96.0, 2096.0), 0.03128138740223666),
#  ((-112.0, 2096.0), 0.031201241638004373),
#  ((272.0, 2032.0), 0.030059714517644838),
#  ((-80.0, 2096.0), 0.03000630818485775),
#  ((352.0, 2016.0), 0.02982515216332154),
#  ((256.0, 2032.0), 0.029737680858648117),
#  ((192.0, 2048.0), 0.029180988138523604),
#  ((368.0, 2016.0), 0.02889676684008775),
#  ((176.0, 2048.0), 0.028838646050581142),
#  ((1264.0, 1856.0), 0.028137231597517125),
#  ((0.0, 2080.0), 0.027107594249968132),
#  ((816.0, 1936.0), 0.026390706708183553),
#  ((992.0, 1904.0), 0.026232881203233797),
#  ((544.0, 1984.0), 0.026169828366697515),
#  ((-288.0, 2128.0), 0.026050467993239033),
#  ((-176.0, 2112.0), 0.02599488575735063),
#  ((-272.0, 2128.0), 0.02587361542450322),
#  ((1088.0, 1888.0), 0.025812980258079498),
#  ((-16.0, 2080.0), 0.0257440283064685),
#  ((1360.0, 1840.0), 0.025736896179636353),
#  ((448.0, 2000.0), 0.02555576433480128),
#  ((-256.0, 2128.0), 0.02551096490761502),
#  ((-192.0, 2112.0), 0.025448008777883228),
#  ((464.0, 2000.0), 0.02528740295230401),
#  ((-352.0, 2144.0), 0.024945326808073934),
#  ((896.0, 1920.0), 0.024898762481705475),
#  ((624.0, 1968.0), 0.02478423744847218),
#  ((-368.0, 2144.0), 0.024252132433392706),
#  ((912.0, 1920.0), 0.023793403706230246),
#  ((640.0, 1968.0), 0.023712242520550667),
#  ((-384.0, 2144.0), 0.022975602613946242),
#  ((720.0, 1952.0), 0.0223919770487675),
#  ((-448.0, 2160.0), 0.01734233454481171),
#  ((-464.0, 2160.0), 0.016132532420472676),
#  ((-528.0, 2176.0), 0.010980283996938648),
#  ((-544.0, 2176.0), 0.009945811309164498),
#  ((-560.0, 2176.0), 0.008947797086688174),
#  ((-624.0, 2192.0), 0.005306930957337411),
#  ((-640.0, 2192.0), 0.004535210657399323),
#  ((-656.0, 2192.0), 0.0037634903574612338),
#  ((-704.0, 2208.0), 0.00163879350911665),
#  ((-720.0, 2208.0), 0.001406697178308202),
#  ((-736.0, 2208.0), 0.001174600847499754)]

# %%
# %matplotlib widget
fig, ax = mplt.xz_subplots()

plots = predict.plot_throws(fig, ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
predict2 = strongholds.Predict(grid=grid, heatmap=heatmap, rng=fixed_rng)
predict2.add_throw(strongholds.rectpoint(1199.63, -139.09),
                   -161.149, 1e-2)
predict2.cumulative_probs.view()
# Out:
# [((1600.0, -1312.0), 0.4570539370885335),
#  ((1824.0, -1968.0), 0.27200855829121423),
#  ((1808.0, -1920.0), 0.27093750462025235)]

# %%
predict3 = strongholds.Predict(grid=grid, heatmap=heatmap, rng=fixed_rng)
predict3.add_throw(strongholds.rectpoint(85.65, 696.62), -29.83, 1e-2)
predict3.cumulative_probs.view()
# Out:
# [((512.0, 1440.0), 0.47688375871395505),
#  ((576.0, 1552.0), 0.41378142069387575),
#  ((1136.0, 2528.0), 0.10933482059216927)]
